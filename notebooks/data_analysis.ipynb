# %%
import pandas as pd
import os
os.chdir('..')

# %%
df_android_raw = df = pd.read_csv("data/android_sdk_totins_31oct2023.csv", engine="python")
df_ios_raw = pd.read_csv('data/ios_sdk_totins_31oct2023.csv')

# %%
df_android_raw.head()
# Out:
#      id  android_totins_31oct2023         name company  \
# 0    10                     79418     AdColony    None
# 1   100                        14      Aurasma    None
# 2  1000                    199650  Android Pay    None
# 3  1001                    849357     Firebase    None
# 4  1002                      1059        GetUI    None
#
#                                       url       _function  \
# 0                            adcolony.com      AD_NETWORK
# 1                             Aurasma.com    MEDIA_PLAYER
# 2  https://developers.google.com/android/        DEV_TOOL
# 3            https://firebase.google.com/       ANALYTICS
# 4                   http://www.getui.com/  PUSH_MESSAGING
#
#                                 other_stores
# 0   [{'store': 'itunes_connect', 'id': 721}]
# 1                                         []
# 2                                         []
# 3  [{'store': 'itunes_connect', 'id': 4611}]
# 4                                         []

# %%
df_ios_raw.head()
# Out:
#      id  ios_totins_31oct2023      name company  \
# 0  1004                   245      UISS    None
# 1   104                   880  RFRateMe    None
# 2   105                  7455    RevMob    None
# 3  1054                   844   Typhoon    None
# 4  1061                 11565  TwinPush    None
#
#                                                url        _function  \
# 0                                             None         DEV_TOOL
# 1  https://www.cocoacontrols.com/controls/rfrateme  SUPPORT_REVIEWS
# 2                                       revmob.com       AD_NETWORK
# 3                                             None         DEV_TOOL
# 4                                     twinpush.com   PUSH_MESSAGING
#
#                            other_stores
# 0                                    []
# 1                                    []
# 2  [{'store': 'google_play', 'id': 64}]
# 3                                    []
# 4                                    []

# %%
df_android_raw = df_android_raw.dropna(subset=["name"])
df_ios_raw = df_ios_raw.dropna(subset=["name"])

# %%
df_ios_raw[df_ios_raw['name'] == 'GetUI']
# Out:
#        id  ios_totins_31oct2023   name company                    url  \
# 401  4574                  9284  GetUI    None  http://www.getui.com/
#
#           _function other_stores
# 401  PUSH_MESSAGING           []

# %%
df_android = df_android_raw.copy()
df_ios = df_ios_raw.copy()

# %%
import ast

def extract_store_id(x):
    try:
        data = ast.literal_eval(x) if isinstance(x, str) else x
        if data and isinstance(data, list):
            return data[0].get("id")
    except Exception:
        return None
    return None

df_android["ios_id"] = df_android["other_stores"].apply(extract_store_id)
df_ios["android_id"] = df_ios["other_stores"].apply(extract_store_id)

# %%
df_android["ios_id"] = df_android["ios_id"].astype("Int64")
df_ios["android_id"] = df_ios["android_id"].astype("Int64")

# %%
df_android = df_android.drop(columns=["other_stores"])
df_ios = df_ios.drop(columns=["other_stores"])

# %%
print(df_android.shape)
print(df_ios.shape)
# Out:
# (1614, 7)
# (1362, 7)

# %%
df_android.head()
# Out:
#      id  android_totins_31oct2023         name company  \
# 0    10                     79418     AdColony    None
# 1   100                        14      Aurasma    None
# 2  1000                    199650  Android Pay    None
# 3  1001                    849357     Firebase    None
# 4  1002                      1059        GetUI    None
#
#                                       url       _function  ios_id
# 0                            adcolony.com      AD_NETWORK     721
# 1                             Aurasma.com    MEDIA_PLAYER    <NA>
# 2  https://developers.google.com/android/        DEV_TOOL    <NA>
# 3            https://firebase.google.com/       ANALYTICS    4611
# 4                   http://www.getui.com/  PUSH_MESSAGING    <NA>

# %%
df_android["ios_id"].isna().sum()
# Out:
# 641

# %%
df_ios.head()
# Out:
#      id  ios_totins_31oct2023      name company  \
# 0  1004                   245      UISS    None
# 1   104                   880  RFRateMe    None
# 2   105                  7455    RevMob    None
# 3  1054                   844   Typhoon    None
# 4  1061                 11565  TwinPush    None
#
#                                                url        _function  \
# 0                                             None         DEV_TOOL
# 1  https://www.cocoacontrols.com/controls/rfrateme  SUPPORT_REVIEWS
# 2                                       revmob.com       AD_NETWORK
# 3                                             None         DEV_TOOL
# 4                                     twinpush.com   PUSH_MESSAGING
#
#    android_id
# 0        <NA>
# 1        <NA>
# 2          64
# 3        <NA>
# 4        <NA>

# %%
df_ios["android_id"].isna().sum()
# Out:
# 381

# %%
df_combined = pd.merge(
    df_android,
    df_ios,
    on="name",
    how="outer",
    suffixes=("_orig_android", "_orig_ios")
)
df_combined
# Out:
#       id_orig_android  android_totins_31oct2023                     name  \
# 0                10.0                   79418.0                 AdColony
# 1               100.0                      14.0                  Aurasma
# 2              1000.0                  199650.0              Android Pay
# 3              1001.0                  849357.0                 Firebase
# 4              1002.0                    1059.0                    GetUI
# ...               ...                       ...                      ...
# 2010              NaN                       NaN                    Woodo
# 2011              NaN                       NaN                   Weixin
# 2012              NaN                       NaN  WebViewJavascriptBridge
# 2013              NaN                       NaN                  Vertigo
# 2014              NaN                       NaN               UPPlatform
#
#      company_orig_android                        url_orig_android  \
# 0                    None                            adcolony.com
# 1                    None                             Aurasma.com
# 2                    None  https://developers.google.com/android/
# 3                    None            https://firebase.google.com/
# 4                    None                   http://www.getui.com/
# ...                   ...                                     ...
# 2010                  NaN                                     NaN
# 2011                  NaN                                     NaN
# 2012                  NaN                                     NaN
# 2013                  NaN                                     NaN
# 2014                  NaN                                     NaN
#
#      _function_orig_android  ios_id  id_orig_ios  ios_totins_31oct2023  \
# 0                AD_NETWORK     721        721.0               39734.0
# 1              MEDIA_PLAYER    <NA>          NaN                   NaN
# 2                  DEV_TOOL    <NA>          NaN                   NaN
# 3                 ANALYTICS    4611       4611.0              245060.0
# 4            PUSH_MESSAGING    <NA>       4574.0                9284.0
# ...                     ...     ...          ...                   ...
# 2010                    NaN    <NA>        845.0                   3.0
# 2011                    NaN    <NA>        862.0                3507.0
# 2012                    NaN    <NA>        868.0               12265.0
# 2013                    NaN    <NA>        947.0                 457.0
# 2014                    NaN    <NA>        965.0                  25.0
#
#      company_orig_ios                                       url_orig_ios  \
# 0                None                                       adcolony.com
# 1                 NaN                                                NaN
# 2                 NaN                                                NaN
# 3                None                        https://firebase.google.com
# 4                None                              http://www.getui.com/
# ...               ...                                                ...
# 2010             None                                           woodo.tv
# 2011             None                                               None
# 2012             None  https://github.com/marcuswestin/WebViewJavascr...
# 2013             None                                        vertigo.com
# 2014             None                                               None
#
#      _function_orig_ios  android_id
# 0            AD_NETWORK          10
# 1                   NaN        <NA>
# 2                   NaN        <NA>
# 3             ANALYTICS        1001
# 4        PUSH_MESSAGING        <NA>
# ...                 ...         ...
# 2010           VIDEO_AD        <NA>
# 2011       DEV_PLATFORM        <NA>
# 2012           DEV_TOOL        <NA>
# 2013           DEV_TOOL        <NA>
# 2014           DEV_TOOL        <NA>
#
# [2015 rows x 13 columns]

# %%
# --- Platforms column
def get_platforms(row):
    platforms = []
    if pd.notna(row.get("id_orig_android")):
        platforms.append("android")
    if pd.notna(row.get("id_orig_ios")):
        platforms.append("ios")
    return platforms

df_combined["platforms"] = df_combined.apply(get_platforms, axis=1)

# --- totins column
df_combined["totins"] = (
    df_combined["android_totins_31oct2023"].fillna(0)
    + df_combined["ios_totins_31oct2023"].fillna(0)
)

# --- Reconcile company, url, and _function
def reconcile(a, b):
    if pd.isna(a) and pd.isna(b):
        return []
    if a == b:
        return [a] if pd.notna(a) else [b]
    return [x for x in [a, b] if pd.notna(x)]

for col in ["company", "url", "_function"]:
    df_combined[col] = df_combined.apply(
        lambda row: reconcile(row.get(f"{col}_orig_android"), row.get(f"{col}_orig_ios")), axis=1
    )

# %%
df_combined
# Out:
#       id_orig_android  android_totins_31oct2023                     name  \
# 0                10.0                   79418.0                 AdColony
# 1               100.0                      14.0                  Aurasma
# 2              1000.0                  199650.0              Android Pay
# 3              1001.0                  849357.0                 Firebase
# 4              1002.0                    1059.0                    GetUI
# ...               ...                       ...                      ...
# 2010              NaN                       NaN                    Woodo
# 2011              NaN                       NaN                   Weixin
# 2012              NaN                       NaN  WebViewJavascriptBridge
# 2013              NaN                       NaN                  Vertigo
# 2014              NaN                       NaN               UPPlatform
#
#      company_orig_android                        url_orig_android  \
# 0                    None                            adcolony.com
# 1                    None                             Aurasma.com
# 2                    None  https://developers.google.com/android/
# 3                    None            https://firebase.google.com/
# 4                    None                   http://www.getui.com/
# ...                   ...                                     ...
# 2010                  NaN                                     NaN
# 2011                  NaN                                     NaN
# 2012                  NaN                                     NaN
# 2013                  NaN                                     NaN
# 2014                  NaN                                     NaN
#
#      _function_orig_android  ios_id  id_orig_ios  ios_totins_31oct2023  \
# 0                AD_NETWORK     721        721.0               39734.0
# 1              MEDIA_PLAYER    <NA>          NaN                   NaN
# 2                  DEV_TOOL    <NA>          NaN                   NaN
# 3                 ANALYTICS    4611       4611.0              245060.0
# 4            PUSH_MESSAGING    <NA>       4574.0                9284.0
# ...                     ...     ...          ...                   ...
# 2010                    NaN    <NA>        845.0                   3.0
# 2011                    NaN    <NA>        862.0                3507.0
# 2012                    NaN    <NA>        868.0               12265.0
# 2013                    NaN    <NA>        947.0                 457.0
# 2014                    NaN    <NA>        965.0                  25.0
#
#      company_orig_ios                                       url_orig_ios  \
# 0                None                                       adcolony.com
# 1                 NaN                                                NaN
# 2                 NaN                                                NaN
# 3                None                        https://firebase.google.com
# 4                None                              http://www.getui.com/
# ...               ...                                                ...
# 2010             None                                           woodo.tv
# 2011             None                                               None
# 2012             None  https://github.com/marcuswestin/WebViewJavascr...
# 2013             None                                        vertigo.com
# 2014             None                                               None
#
#      _function_orig_ios  android_id       platforms     totins company  \
# 0            AD_NETWORK          10  [android, ios]   119152.0  [None]
# 1                   NaN        <NA>       [android]       14.0  [None]
# 2                   NaN        <NA>       [android]   199650.0  [None]
# 3             ANALYTICS        1001  [android, ios]  1094417.0  [None]
# 4        PUSH_MESSAGING        <NA>  [android, ios]    10343.0  [None]
# ...                 ...         ...             ...        ...     ...
# 2010           VIDEO_AD        <NA>           [ios]        3.0  [None]
# 2011       DEV_PLATFORM        <NA>           [ios]     3507.0  [None]
# 2012           DEV_TOOL        <NA>           [ios]    12265.0  [None]
# 2013           DEV_TOOL        <NA>           [ios]      457.0  [None]
# 2014           DEV_TOOL        <NA>           [ios]       25.0  [None]
#
#                                                     url         _function
# 0                                        [adcolony.com]      [AD_NETWORK]
# 1                                         [Aurasma.com]    [MEDIA_PLAYER]
# 2              [https://developers.google.com/android/]        [DEV_TOOL]
# 3     [https://firebase.google.com/, https://firebas...       [ANALYTICS]
# 4                               [http://www.getui.com/]  [PUSH_MESSAGING]
# ...                                                 ...               ...
# 2010                                         [woodo.tv]        [VIDEO_AD]
# 2011                                             [None]    [DEV_PLATFORM]
# 2012  [https://github.com/marcuswestin/WebViewJavasc...        [DEV_TOOL]
# 2013                                      [vertigo.com]        [DEV_TOOL]
# 2014                                             [None]        [DEV_TOOL]
#
# [2015 rows x 18 columns]

# %%
df_combined[df_combined['name'] == 'GetUI']
# Out:
#    id_orig_android  android_totins_31oct2023   name company_orig_android  \
# 4           1002.0                    1059.0  GetUI                 None
#
#         url_orig_android _function_orig_android  ios_id  id_orig_ios  \
# 4  http://www.getui.com/         PUSH_MESSAGING    <NA>       4574.0
#
#    ios_totins_31oct2023 company_orig_ios           url_orig_ios  \
# 4                9284.0             None  http://www.getui.com/
#
#   _function_orig_ios  android_id       platforms   totins company  \
# 4     PUSH_MESSAGING        <NA>  [android, ios]  10343.0  [None]
#
#                        url         _function
# 4  [http://www.getui.com/]  [PUSH_MESSAGING]

# %%
df_combined = df_combined.rename(columns={
    "ios_id": "ios_id_from_android_perspective",
    "android_id": "android_id_from_ios_perspective",
    "_function": "function"
})

# %%
df_combined = df_combined.drop(
    columns=["company_orig_android", "company_orig_ios", 
             "url_orig_android", "url_orig_ios", 
             "_function_orig_android", "_function_orig_ios"]
)
df_combined.head()
# Out:
#    id_orig_android  android_totins_31oct2023         name  \
# 0             10.0                   79418.0     AdColony
# 1            100.0                      14.0      Aurasma
# 2           1000.0                  199650.0  Android Pay
# 3           1001.0                  849357.0     Firebase
# 4           1002.0                    1059.0        GetUI
#
#    ios_id_from_android_perspective  id_orig_ios  ios_totins_31oct2023  \
# 0                              721        721.0               39734.0
# 1                             <NA>          NaN                   NaN
# 2                             <NA>          NaN                   NaN
# 3                             4611       4611.0              245060.0
# 4                             <NA>       4574.0                9284.0
#
#    android_id_from_ios_perspective       platforms     totins company  \
# 0                               10  [android, ios]   119152.0  [None]
# 1                             <NA>       [android]       14.0  [None]
# 2                             <NA>       [android]   199650.0  [None]
# 3                             1001  [android, ios]  1094417.0  [None]
# 4                             <NA>  [android, ios]    10343.0  [None]
#
#                                                  url          function
# 0                                     [adcolony.com]      [AD_NETWORK]
# 1                                      [Aurasma.com]    [MEDIA_PLAYER]
# 2           [https://developers.google.com/android/]        [DEV_TOOL]
# 3  [https://firebase.google.com/, https://firebas...       [ANALYTICS]
# 4                            [http://www.getui.com/]  [PUSH_MESSAGING]

# %%
df_combined.rename(columns={
    "id_orig_android": "android_id",
    "id_orig_ios": "ios_id",
    "android_totins_31oct2023": "android_totins",
    "ios_totins_31oct2023": "ios_totins",
    "_function": "function"
}, inplace=True)

df_combined["ios_id"] = df_combined["ios_id"].astype("Int64")
df_combined["android_id"] = df_combined["android_id"].astype("Int64")
df_combined["android_totins"] = df_combined["android_totins"].astype("Int64")
df_combined["ios_totins"] = df_combined["ios_totins"].astype("Int64")
df_combined["totins"] = df_combined["totins"].astype("Int64")
df_combined["ios_id_from_android_perspective"] = df_combined["ios_id_from_android_perspective"].astype("Int64")
df_combined["android_id_from_ios_perspective"] = df_combined["android_id_from_ios_perspective"].astype("Int64")

# %%
df_final = df_combined[[
    "android_id",
    "android_id_from_ios_perspective",
    "ios_id",
    "ios_id_from_android_perspective",
    "name",
    "company",
    "android_totins",
    "ios_totins",
    "totins",
    "function",
    "platforms",
    "url"
]].copy()

# %%
df_final.head()
# Out:
#    android_id  android_id_from_ios_perspective  ios_id  \
# 0          10                               10     721
# 1         100                             <NA>    <NA>
# 2        1000                             <NA>    <NA>
# 3        1001                             1001    4611
# 4        1002                             <NA>    4574
#
#    ios_id_from_android_perspective         name company  android_totins  \
# 0                              721     AdColony  [None]           79418
# 1                             <NA>      Aurasma  [None]              14
# 2                             <NA>  Android Pay  [None]          199650
# 3                             4611     Firebase  [None]          849357
# 4                             <NA>        GetUI  [None]            1059
#
#    ios_totins   totins          function       platforms  \
# 0       39734   119152      [AD_NETWORK]  [android, ios]
# 1        <NA>       14    [MEDIA_PLAYER]       [android]
# 2        <NA>   199650        [DEV_TOOL]       [android]
# 3      245060  1094417       [ANALYTICS]  [android, ios]
# 4        9284    10343  [PUSH_MESSAGING]  [android, ios]
#
#                                                  url
# 0                                     [adcolony.com]
# 1                                      [Aurasma.com]
# 2           [https://developers.google.com/android/]
# 3  [https://firebase.google.com/, https://firebas...
# 4                            [http://www.getui.com/]

# %%
df_final.shape
# Out:
# (2015, 12)

# %%
# Pick first element of any column that has value of list.

df_final["function"] = df_final["function"].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else None)
df_final["url"] = df_final["url"].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else None)
df_final["company"] = df_final["company"].apply(
    lambda x: x[0] if isinstance(x, list) and len(x) > 0 else None
)

df_final["company"] = df_final["company"].apply(
    lambda x: (
        [pd.NA if (v is None or str(v).lower() == "none") else v for v in x]
        if isinstance(x, list) 
        else (pd.NA if (x is None or str(x).lower() == "none") else x)
    )
)
df_final["url"] = df_final["url"].apply(
    lambda x: (
        [pd.NA if (v is None or str(v).lower() == "none") else v for v in x]
        if isinstance(x, list) 
        else (pd.NA if (x is None or str(x).lower() == "none") else x)
    )
)

# %%
df_final.head()
# Out:
#    android_id  android_id_from_ios_perspective  ios_id  \
# 0          10                               10     721
# 1         100                             <NA>    <NA>
# 2        1000                             <NA>    <NA>
# 3        1001                             1001    4611
# 4        1002                             <NA>    4574
#
#    ios_id_from_android_perspective         name company  android_totins  \
# 0                              721     AdColony    <NA>           79418
# 1                             <NA>      Aurasma    <NA>              14
# 2                             <NA>  Android Pay    <NA>          199650
# 3                             4611     Firebase    <NA>          849357
# 4                             <NA>        GetUI    <NA>            1059
#
#    ios_totins   totins        function       platforms  \
# 0       39734   119152      AD_NETWORK  [android, ios]
# 1        <NA>       14    MEDIA_PLAYER       [android]
# 2        <NA>   199650        DEV_TOOL       [android]
# 3      245060  1094417       ANALYTICS  [android, ios]
# 4        9284    10343  PUSH_MESSAGING  [android, ios]
#
#                                       url
# 0                            adcolony.com
# 1                             Aurasma.com
# 2  https://developers.google.com/android/
# 3            https://firebase.google.com/
# 4                   http://www.getui.com/

# %%
df_final = df_final.sort_values(by="totins", ascending=False).reset_index(drop=True)
df_final.head()
# Out:
#    android_id  android_id_from_ios_perspective  ios_id  \
# 0         962                              962    4500
# 1         566                              566     350
# 2        1001                             1001    4611
# 3         992                              992    5146
# 4        1061                             1061    4612
#
#    ios_id_from_android_perspective                           name company  \
# 0                             4500      Google Mobile Ads (AdMob)    <NA>
# 1                              350                         Google    <NA>
# 2                             4611                       Firebase    <NA>
# 3                             5146                 Google Sign-In    <NA>
# 4                             4612  Google Analytics for Firebase    <NA>
#
#    android_totins  ios_totins   totins      function       platforms  \
# 0         1018573      282919  1301492    AD_NETWORK  [android, ios]
# 1         1222566       54686  1277252  DEV_PLATFORM  [android, ios]
# 2          849357      245060  1094417     ANALYTICS  [android, ios]
# 3          965611       51321  1016932        SOCIAL  [android, ios]
# 4          699395      222457   921852     ANALYTICS  [android, ios]
#
#                                            url
# 0                                         <NA>
# 1                                   google.com
# 2                 https://firebase.google.com/
# 3       https://developers.google.com/android/
# 4  https://firebase.google.com/docs/analytics/

# %%
df_final.shape
# Out:
# (2015, 12)

# %%
df_final.to_csv("data/sdk_combined.csv", index=False)
